# %%
import sklearn
import pandas as pd
import numpy
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Pages.csv")
df.head()
# Out:
#    id                                                url  \
# 0   1  https://www.imdb.com/title/tt0371746/?ref_=tt_...
# 1   2  https://www.imdb.com//title/tt1300854/?ref_=tt...
# 2   3  https://www.imdb.com//title/tt2015381/?ref_=tt...
# 3   4  https://www.imdb.com//title/tt1228705/?ref_=tt...
# 4   5  https://www.imdb.com//title/tt2395427/?ref_=tt...
#
#                       name                              genre     director  \
# 0                 Iron Man          Action, Adventure, Sci-Fi  Jon Favreau
# 1               Iron Man 3          Action, Adventure, Sci-Fi  Shane Black
# 2  Guardians of the Galaxy  Action, Adventure, Comedy, Sci-Fi   James Gunn
# 3               Iron Man 2                     Action, Sci-Fi  Jon Favreau
# 4  Avengers: Age of Ultron          Action, Adventure, Sci-Fi  Joss Whedon
#
#   contentRating  datePublished  \
# 0         PG-13         2008.0
# 1         PG-13         2013.0
# 2         PG-13         2014.0
# 3         PG-13         2010.0
# ...

# %%
df.columns
# Out:
# Index(['id', 'url', 'name', 'genre', 'director', 'contentRating',
#        'datePublished', 'keywords', 'description', 'averageRating',
#        'ratingCount', 'releasedCountry', 'duration'],
#       dtype='object')

# %%
df = df.drop(columns=["id", "url", "director", "contentRating", "description", "duration", "keywords"])

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['name', 'genre', 'datePublished', 'averageRating', 'ratingCount',
#        'releasedCountry'],
#       dtype='object')

# %%
df["genre"] = df.genre.apply(lambda x: x[0:-1].split(','))
df["genre"][0]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# ['Action', ' Adventure', ' Sci-F']

# %%
df.reset_index(inplace=True)
rows = []
_ = df.apply(lambda row: [rows.append([row['name'], row['datePublished'],  nn]) 
                         for nn in row.genre], axis=1)
df_new = pd.DataFrame(rows, columns=df.columns[:3]).set_index(['name', 'dataPublished'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-26-3303617111b1> in <module>()
#       3 _ = df.apply(lambda row: [rows.append([row['name'], row['datePublished'],  nn])
#       4                          for nn in row.genre], axis=1)
# ----> 5 df_new = pd.DataFrame(rows, columns=df.columns).set_index(['name', 'dataPublished', 'averageRating', 'ratingCount', 'releaseCounty'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     385                     if is_named_tuple(data[0]) and columns is None:
#     386                         columns = data[0]._fields
# --> 387                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     388                     columns = _ensure_index(columns)
#     389
#
# ...

# %%
Category = []
rating = []
df.quantile(0.1)
# Out:
# datePublished    1974.0
# averageRating       5.0
# ratingCount       677.0
# Name: 0.1, dtype: float64

# %%
df.head(50)
# Out:
#                                        name  \
# 0                                  Iron Man
# 1                                Iron Man 3
# 2                   Guardians of the Galaxy
# 3                                Iron Man 2
# 4                   Avengers: Age of Ultron
# 5                                  Deadpool
# 6                            Thor: Ragnarok
# 7                                      Thor
# 8                             Black Panther
# 9       Captain America: The Winter Soldier
# 10                      The Incredible Hulk
# 11                             Wonder Woman
# 12           Guardians of the Galaxy Vol. 2
# 13                   Spider-Man: Homecoming
# 14                     Thor: The Dark World
# 15                                  Ant-Man
# 16                               Deadpool 2
# 17           Jurassic World: Fallen Kingdom
# 18                                     Hulk
# 19                           Doctor Strange
# ...

# %%
#percentile  rating
# 0.25        5.6
# 0.5         6.5
# 0.75        7.2
# 1           9.2

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-ff961987ce0a> in <module>()
#       1
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
#
# NameError: name 'X' is not defined
